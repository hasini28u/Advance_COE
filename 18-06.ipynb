# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/heart(in).csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['Sex'] = df['Sex'].map({'M':0,'F':1})
df
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40    0           ATA        140          289          0     Normal
# 1     49    1           NAP        160          180          0     Normal
# 2     37    0           ATA        130          283          0         ST
# 3     48    1           ASY        138          214          0     Normal
# 4     54    0           NAP        150          195          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 913   45    0            TA        110          264          0     Normal
# 914   68    0           ASY        144          193          1     Normal
# 915   57    0           ASY        130          131          0     Normal
# 916   57    1           ATA        130          236          0        LVH
# 917   38    0           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df['ChestPainType']= df['ChestPainType'].map({'ATA':0,'NAP':1,'ASY':2,'TA':3})
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40    0              0        140          289          0     Normal
# 1     49    1              1        160          180          0     Normal
# 2     37    0              0        130          283          0         ST
# 3     48    1              2        138          214          0     Normal
# 4     54    0              1        150          195          0     Normal
# ..   ...  ...            ...        ...          ...        ...        ...
# 913   45    0              3        110          264          0     Normal
# 914   68    0              2        144          193          1     Normal
# 915   57    0              2        130          131          0     Normal
# 916   57    1              0        130          236          0        LVH
# 917   38    0              1        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df['RestingECG'] = df['RestingECG'].map({'Normal':0,'ST':1,'LVH':2})
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              0        140          289          0           0
# 1     49    1              1        160          180          0           0
# 2     37    0              0        130          283          0           1
# 3     48    1              2        138          214          0           0
# 4     54    0              1        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              3        110          264          0           0
# 914   68    0              2        144          193          1           0
# 915   57    0              2        130          131          0           0
# 916   57    1              0        130          236          0           2
# 917   38    0              1        138          175          0           0
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['ExerciseAngina'].value_counts()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64

# %%
df['ExerciseAngina'] = df['ExerciseAngina'].map({'Y':0,'N':1})
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              0        140          289          0           0
# 1     49    1              1        160          180          0           0
# 2     37    0              0        130          283          0           1
# 3     48    1              2        138          214          0           0
# 4     54    0              1        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              3        110          264          0           0
# 914   68    0              2        144          193          1           0
# 915   57    0              2        130          131          0           0
# 916   57    1              0        130          236          0           2
# 917   38    0              1        138          175          0           0
#
#      MaxHR  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172               1      0.0       Up             0
# 1      156               1      1.0     Flat             1
# 2       98               1      0.0       Up             0
# 3      108               0      1.5     Flat             1
# 4      122               1      0.0       Up             0
# ..     ...             ...      ...      ...           ...
# 913    132               1      1.2     Flat             1
# 914    141               1      3.4     Flat             1
# 915    115               0      1.2     Flat             1
# 916    174               1      0.0     Flat             1
# 917    173               1      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
df['ST_Slope'] = df['ST_Slope'].map({'Up':0,'Flat':1,'Down':2})
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              0        140          289          0           0
# 1     49    1              1        160          180          0           0
# 2     37    0              0        130          283          0           1
# 3     48    1              2        138          214          0           0
# 4     54    0              1        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              3        110          264          0           0
# 914   68    0              2        144          193          1           0
# 915   57    0              2        130          131          0           0
# 916   57    1              0        130          236          0           2
# 917   38    0              1        138          175          0           0
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               1      0.0         0             0
# 1      156               1      1.0         1             1
# 2       98               1      0.0         0             0
# 3      108               0      1.5         1             1
# 4      122               1      0.0         0             0
# ..     ...             ...      ...       ...           ...
# 913    132               1      1.2         1             1
# 914    141               1      3.4         1             1
# 915    115               0      1.2         1             1
# 916    174               1      0.0         1             1
# 917    173               1      0.0         0             0
#
# [918 rows x 12 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
df[['Age',	'Sex',	'ChestPainType','RestingBP','Cholesterol','FastingBS','RestingECG','MaxHR','ExerciseAngina','Oldpeak','ST_Slope'	]]= sc.fit_transform(df[['Age',	'Sex',	'ChestPainType',	'RestingBP',	'Cholesterol',	'FastingBS',	'RestingECG','MaxHR','ExerciseAngina','Oldpeak','ST_Slope'	]])
df.head()
# Out:
#         Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0  0.244898  0.0       0.000000       0.70     0.479270        0.0
# 1  0.428571  1.0       0.333333       0.80     0.298507        0.0
# 2  0.183673  0.0       0.000000       0.65     0.469320        0.0
# 3  0.408163  1.0       0.666667       0.69     0.354892        0.0
# 4  0.530612  0.0       0.333333       0.75     0.323383        0.0
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0         0.0  0.788732             1.0  0.295455       0.0             0
# 1         0.0  0.676056             1.0  0.409091       0.5             1
# 2         0.5  0.267606             1.0  0.295455       0.0             0
# 3         0.0  0.338028             0.0  0.465909       0.5             1
# 4         0.0  0.436620             1.0  0.295455       0.0             0

# %%
X = df[['Age',	'Sex',	'ChestPainType',	'RestingBP',	'Cholesterol',	'FastingBS',	'RestingECG','MaxHR','ExerciseAngina','Oldpeak','ST_Slope'	]]
y = df[['HeartDisease']]

# %%
print(X.shape)
print(y.shape)
# Out:
# (918, 11)
# (918, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from keras import Sequential
from keras.layers import Dense,Dropout
from keras.callbacks import EarlyStopping,ModelCheckpoint
model = Sequential()
model.add(Dense(units=3,input_dim=11,kernel_initializer='random_uniform',activation='relu'))
model.add(Dense(units=18,kernel_initializer='he_uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=28,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=39,kernel_initializer='he_uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=60,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=30,kernel_initializer='he_uniform',activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=24,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=15,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=4,kernel_initializer='he_uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='he_uniform'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='mean_square_error',optimizer='adam',metrics=['mse'])

# %%
early_stop = EarlyStopping(
    monitor='val_recall',
    patience = 9,
    restore_best_weights=True,
    verbose=1
)

# %%
checkpoint = ModelCheckpoint(
    'best_model.keras', #.keras is better than h5
    monitor='val_recall',
    verbose=1,
    save_best_only=True
)

# %%
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['recall'])

# %%
model.fit(x_train,y_train,epochs=100,batch_size=20,verbose=1,callbacks=[early_stop,checkpoint],validation_split=0.3)
# Out:
# Epoch 1/100
# 20/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4007 - recall: 0.1012
# Epoch 1: val_recall improved from inf to 0.78512, saving model to best_model.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.3769 - recall: 0.1819 - val_loss: 0.1872 - val_recall: 0.7851
# Epoch 2/100
# 17/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1863 - recall: 0.6386
# Epoch 2: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1831 - recall: 0.6641 - val_loss: 0.1492 - val_recall: 0.8347
# Epoch 3/100
# 20/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1522 - recall: 0.7827
# Epoch 3: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1526 - recall: 0.7774 - val_loss: 0.1336 - val_recall: 0.8430
# Epoch 4/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1520 - recall: 0.7994
# Epoch 4: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1504 - recall: 0.7981 - val_loss: 0.1302 - val_recall: 0.9008
# Epoch 5/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1310 - recall: 0.8182
# Epoch 5: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1321 - recall: 0.8174 - val_loss: 0.1377 - val_recall: 0.8347
# Epoch 6/100
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1471 - recall: 0.8271
# Epoch 6: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1433 - recall: 0.8324 - val_loss: 0.1410 - val_recall: 0.8264
# Epoch 7/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1234 - recall: 0.8787
# Epoch 7: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1234 - recall: 0.8785 - val_loss: 0.1357 - val_recall: 0.8595
# Epoch 8/100
# 19/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1203 - recall: 0.8174
# Epoch 8: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1202 - recall: 0.8248 - val_loss: 0.1337 - val_recall: 0.9008
# Epoch 9/100
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1064 - recall: 0.9134
# Epoch 9: val_recall did not improve from 0.78512
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1080 - recall: 0.9116 - val_loss: 0.1341 - val_recall: 0.8843
# Epoch 10/100
# 15/26 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1255 - recall: 0.8361
# Epoch 10: val_recall improved from 0.78512 to 0.74380, saving model to best_model.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1235 - recall: 0.8517 - val_loss: 0.1497 - val_recall: 0.7438
# Epoch 11/100
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1202 - recall: 0.8752
# Epoch 11: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1198 - recall: 0.8808 - val_loss: 0.1305 - val_recall: 0.8843
# Epoch 12/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1083 - recall: 0.8669
# Epoch 12: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1082 - recall: 0.8721 - val_loss: 0.1348 - val_recall: 0.9587
# Epoch 13/100
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1178 - recall: 0.9587
# Epoch 13: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1181 - recall: 0.9527 - val_loss: 0.1240 - val_recall: 0.9587
# Epoch 14/100
# 20/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1173 - recall: 0.9214
# Epoch 14: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1166 - recall: 0.9186 - val_loss: 0.1125 - val_recall: 0.9421
# Epoch 15/100
# 22/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1049 - recall: 0.9181
# Epoch 15: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1050 - recall: 0.9159 - val_loss: 0.1272 - val_recall: 0.9504
# Epoch 16/100
# 23/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1093 - recall: 0.9447
# Epoch 16: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1093 - recall: 0.9412 - val_loss: 0.1117 - val_recall: 0.9421
# Epoch 17/100
# 17/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1295 - recall: 0.9266
# Epoch 17: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1247 - recall: 0.9234 - val_loss: 0.1163 - val_recall: 0.9504
# Epoch 18/100
# 20/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1053 - recall: 0.9387
# Epoch 18: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1057 - recall: 0.9339 - val_loss: 0.1086 - val_recall: 0.9421
# Epoch 19/100
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1145 - recall: 0.9440
# Epoch 19: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1141 - recall: 0.9432 - val_loss: 0.1073 - val_recall: 0.9421
# Epoch 20/100
# 22/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1100 - recall: 0.9229
# Epoch 20: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1092 - recall: 0.9211 - val_loss: 0.1161 - val_recall: 0.9504
# Epoch 21/100
# 22/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1090 - recall: 0.9347
# Epoch 21: val_recall did not improve from 0.74380
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1075 - recall: 0.9355 - val_loss: 0.1081 - val_recall: 0.9421
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
loss,recall = model.evaluate(x_test,y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1603 - recall: 0.9021

# %%
loss
# Out:
# 0.1461765468120575

# %%
recall

# %%
0.9134615659713745

# %%
0.9134615659713745
